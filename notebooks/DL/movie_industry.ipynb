# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline

# %%
movie_industry = pd.read_csv("movie_industry.csv", encoding = "ISO-8859-1")

# %%
movie_industry
# Out:
#           budget                                  company    country  \
# 0      8000000.0            Columbia Pictures Corporation        USA
# 1      6000000.0                       Paramount Pictures        USA
# 2     15000000.0                       Paramount Pictures        USA
# 3     18500000.0   Twentieth Century Fox Film Corporation        USA
# 4      9000000.0                     Walt Disney Pictures        USA
# 5      6000000.0                                  Hemdale         UK
# 6     25000000.0                   Henson Associates (HA)         UK
# 7      6000000.0  De Laurentiis Entertainment Group (DEG)        USA
# 8      9000000.0                       Paramount Pictures        USA
# 9     15000000.0                     SLM Production Group        USA
# 10     8800000.0                            Rimfire Films  Australia
# 11    16000000.0           Thorn EMI Screen Entertainment         UK
# 12     6000000.0   Twentieth Century Fox Film Corporation        USA
# ...

# %%
movie_industry.shape
# Out:
# (6820, 15)

# %%
movie_industry["log_gross"] = np.log10(movie_industry["gross"])

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x="score", y="log_gross", data=movie_industry)
plt.xlabel("Score", fontsize=18)
plt.ylabel("Log10_Gross", fontsize=18)
# Out:
# Text(0, 0.5, 'Log10_Gross')

# %%
movie_industry["ROI"] = movie_industry["gross"]/movie_industry["budget"]

# %%
plt.figure(figsize=(15, 8))
sns.lineplot(movie_industry["released"], np.log10(movie_industry["ROI"]))
plt.xlabel("Date", fontsize=18)
plt.ylabel("Log10_ROI", fontsize=18)
plt.tick_params(
    axis='x',   
    which='both',      
    labelbottom=False)
