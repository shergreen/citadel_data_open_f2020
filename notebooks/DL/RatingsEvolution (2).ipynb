# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.vector_ar.var_model import VAR
# %matplotlib inline

# %%
movies = pd.read_csv("movies.csv")
ratings = pd.read_csv("ratings.csv")

# %%
movies.head(5)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies.shape
# Out:
# (58098, 3)

# %%
ratings.head(5)
# Out:
#    userId  movieId  rating   timestamp
# 0       1      307     3.5  1256677221
# 1       1      481     3.5  1256677456
# 2       1     1091     1.5  1256677471
# 3       1     1257     4.5  1256677460
# 4       1     1449     4.5  1256677264

# %%
ratings.shape
# Out:
# (27753444, 4)

# %% [markdown]
# ## Reformating movies data

# %%
movies_cleaned = pd.DataFrame(movies.genres.str.split("|").tolist(), index=movies.movieId)
movies_cleaned.head()
# Out:
#                  0          1         2       3        4     5     6     7  \
# movieId
# 1        Adventure  Animation  Children  Comedy  Fantasy  None  None  None
# 2        Adventure   Children   Fantasy    None     None  None  None  None
# 3           Comedy    Romance      None    None     None  None  None  None
# 4           Comedy      Drama   Romance    None     None  None  None  None
# 5           Comedy       None      None    None     None  None  None  None
#
#             8     9
# movieId
# 1        None  None
# 2        None  None
# 3        None  None
# 4        None  None
# 5        None  None

# %%
movies_cleaned2 = movies_cleaned.stack().reset_index()
movies_cleaned2.head(10)
# Out:
#    movieId  level_1          0
# 0        1        0  Adventure
# 1        1        1  Animation
# 2        1        2   Children
# 3        1        3     Comedy
# 4        1        4    Fantasy
# 5        2        0  Adventure
# 6        2        1   Children
# 7        2        2    Fantasy
# 8        3        0     Comedy
# 9        3        1    Romance

# %%
movies_genres = movies_cleaned2.drop("level_1", axis=1).rename(columns={0:"genres"})
movies_genres.head()
# Out:
#    movieId     genres
# 0        1  Adventure
# 1        1  Animation
# 2        1   Children
# 3        1     Comedy
# 4        1    Fantasy

# %%
movies = pd.merge(movies.drop("genres",axis=1), movies_genres)
movies.head(10)
# Out:
#    movieId                    title     genres
# 0        1         Toy Story (1995)  Adventure
# 1        1         Toy Story (1995)  Animation
# 2        1         Toy Story (1995)   Children
# 3        1         Toy Story (1995)     Comedy
# 4        1         Toy Story (1995)    Fantasy
# 5        2           Jumanji (1995)  Adventure
# 6        2           Jumanji (1995)   Children
# 7        2           Jumanji (1995)    Fantasy
# 8        3  Grumpier Old Men (1995)     Comedy
# 9        3  Grumpier Old Men (1995)    Romance

# %%
movies.shape
# Out:
# (106107, 3)

# %% [markdown]
# ## Reformating ratings data

# %%
import time

# %%
ratings["rating_date"] = ratings["timestamp"].apply(lambda x: time.strftime('%Y-%m', time.localtime(x)))
ratings["rating_year"] = ratings["timestamp"].apply(lambda x:  time.strftime('%Y', time.localtime(x)))

# %%
ratings.head(50)
# Out:
#     userId  movieId  rating   timestamp rating_date rating_year
# 0        1      307     3.5  1256677221     2009-10        2009
# 1        1      481     3.5  1256677456     2009-10        2009
# 2        1     1091     1.5  1256677471     2009-10        2009
# 3        1     1257     4.5  1256677460     2009-10        2009
# 4        1     1449     4.5  1256677264     2009-10        2009
# 5        1     1590     2.5  1256677236     2009-10        2009
# 6        1     1591     1.5  1256677475     2009-10        2009
# 7        1     2134     4.5  1256677464     2009-10        2009
# 8        1     2478     4.0  1256677239     2009-10        2009
# 9        1     2840     3.0  1256677500     2009-10        2009
# 10       1     2986     2.5  1256677496     2009-10        2009
# 11       1     3020     4.0  1256677260     2009-10        2009
# 12       1     3424     4.5  1256677444     2009-10        2009
# 13       1     3698     3.5  1256677243     2009-10        2009
# 14       1     3826     2.0  1256677210     2009-10        2009
# 15       1     3893     3.5  1256677486     2009-10        2009
# 16       2      170     3.5  1192913581     2007-10        2007
# 17       2      849     3.5  1192913537     2007-10        2007
# 18       2     1186     3.5  1192913611     2007-10        2007
# 19       2     1235     3.0  1192913585     2007-10        2007
# 20       2     1244     3.0  1192913551     2007-10        2007
# 21       2     1296     4.5  1192913608     2007-10        2007
# 22       2     1663     3.0  1192913565     2007-10        2007
# 23       2     1962     4.0  1192913533     2007-10        2007
# 24       2     2108     3.5  1192913541     2007-10        2007
# 25       2     2243     4.5  1192913604     2007-10        2007
# 26       2     2352     4.0  1192913575     2007-10        2007
# 27       2     2707     3.5  1192913600     2007-10        2007
# 28       2     2746     4.0  1192913548     2007-10        2007
# 29       2     2915     3.5  1192913562     2007-10        2007
# 30       2     3363     4.0  1192913596     2007-10        2007
# 31       3      640     3.0   945141610     1999-12        1999
# 32       3      828     4.0   945141610     1999-12        1999
# 33       3      960     3.0   945141407     1999-12        1999
# 34       3     1221     4.0   945141407     1999-12        1999
# 35       3     1321     4.0   945141407     1999-12        1999
# 36       3     1645     4.0   945141611     1999-12        1999
# 37       3     1825     3.0   945141611     1999-12        1999
# 38       3     1985     2.0   945141611     1999-12        1999
# 39       3     2024     3.0   945141611     1999-12        1999
# 40       3     2028     5.0   945141611     1999-12        1999
# 41       3     3171     4.0   945141407     1999-12        1999
# 42       4        1     4.0  1113765937     2005-04        2005
# 43       4        2     4.0  1113767306     2005-04        2005
# 44       4        5     2.0  1123990453     2005-08        2005
# 45       4        6     4.5  1113767242     2005-04        2005
# 46       4       10     4.0  1113765995     2005-04        2005
# 47       4       11     3.5  1113767280     2005-04        2005
# 48       4       16     4.0  1113765691     2005-04        2005
# 49       4       19     2.0  1113767324     2005-04        2005

# %%
movie_ratings = ratings.merge(movies.drop("title", axis=1), on="movieId", how="inner")

# %%
movie_ratings[movie_ratings.movieId==1]  # ratings of the movie with Id=1
# Out:
#          userId  movieId  rating   timestamp rating_date rating_year  \
# 896082        4        1     4.0  1113765937     2005-04        2005
# 896083        4        1     4.0  1113765937     2005-04        2005
# 896084        4        1     4.0  1113765937     2005-04        2005
# 896085        4        1     4.0  1113765937     2005-04        2005
# 896086        4        1     4.0  1113765937     2005-04        2005
# 896087       10        1     5.0   948885850     2000-01        2000
# 896088       10        1     5.0   948885850     2000-01        2000
# 896089       10        1     5.0   948885850     2000-01        2000
# 896090       10        1     5.0   948885850     2000-01        2000
# 896091       10        1     5.0   948885850     2000-01        2000
# 896092       14        1     4.5  1442169375     2015-09        2015
# 896093       14        1     4.5  1442169375     2015-09        2015
# 896094       14        1     4.5  1442169375     2015-09        2015
# 896095       14        1     4.5  1442169375     2015-09        2015
# 896096       14        1     4.5  1442169375     2015-09        2015
# 896097       15        1     4.0  1370810063     2013-06        2013
# 896098       15        1     4.0  1370810063     2013-06        2013
# 896099       15        1     4.0  1370810063     2013-06        2013
# 896100       15        1     4.0  1370810063     2013-06        2013
# 896101       15        1     4.0  1370810063     2013-06        2013
# 896102       22        1     4.0  1237622631     2009-03        2009
# 896103       22        1     4.0  1237622631     2009-03        2009
# 896104       22        1     4.0  1237622631     2009-03        2009
# 896105       22        1     4.0  1237622631     2009-03        2009
# 896106       22        1     4.0  1237622631     2009-03        2009
# 896107       25        1     4.0   866491842     1997-06        1997
# 896108       25        1     4.0   866491842     1997-06        1997
# 896109       25        1     4.0   866491842     1997-06        1997
# 896110       25        1     4.0   866491842     1997-06        1997
# 896111       25        1     4.0   866491842     1997-06        1997
# ...         ...      ...     ...         ...         ...         ...
# 1238397  283199        1     5.0  1455716281     2016-02        2016
# 1238398  283199        1     5.0  1455716281     2016-02        2016
# 1238399  283199        1     5.0  1455716281     2016-02        2016
# 1238400  283199        1     5.0  1455716281     2016-02        2016
# 1238401  283199        1     5.0  1455716281     2016-02        2016
# 1238402  283208        1     4.5  1092142493     2004-08        2004
# 1238403  283208        1     4.5  1092142493     2004-08        2004
# 1238404  283208        1     4.5  1092142493     2004-08        2004
# 1238405  283208        1     4.5  1092142493     2004-08        2004
# 1238406  283208        1     4.5  1092142493     2004-08        2004
# 1238407  283215        1     4.0   854982102     1997-02        1997
# 1238408  283215        1     4.0   854982102     1997-02        1997
# 1238409  283215        1     4.0   854982102     1997-02        1997
# 1238410  283215        1     4.0   854982102     1997-02        1997
# 1238411  283215        1     4.0   854982102     1997-02        1997
# 1238412  283217        1     5.0   831280017     1996-05        1996
# 1238413  283217        1     5.0   831280017     1996-05        1996
# 1238414  283217        1     5.0   831280017     1996-05        1996
# 1238415  283217        1     5.0   831280017     1996-05        1996
# 1238416  283217        1     5.0   831280017     1996-05        1996
# 1238417  283219        1     4.0  1467480019     2016-07        2016
# 1238418  283219        1     4.0  1467480019     2016-07        2016
# 1238419  283219        1     4.0  1467480019     2016-07        2016
# 1238420  283219        1     4.0  1467480019     2016-07        2016
# 1238421  283219        1     4.0  1467480019     2016-07        2016
# 1238422  283228        1     4.5  1379882801     2013-09        2013
# 1238423  283228        1     4.5  1379882801     2013-09        2013
# 1238424  283228        1     4.5  1379882801     2013-09        2013
# 1238425  283228        1     4.5  1379882801     2013-09        2013
# 1238426  283228        1     4.5  1379882801     2013-09        2013
#
#             genres
# 896082   Adventure
# 896083   Animation
# 896084    Children
# 896085      Comedy
# 896086     Fantasy
# 896087   Adventure
# 896088   Animation
# 896089    Children
# 896090      Comedy
# 896091     Fantasy
# 896092   Adventure
# 896093   Animation
# 896094    Children
# 896095      Comedy
# 896096     Fantasy
# 896097   Adventure
# 896098   Animation
# 896099    Children
# 896100      Comedy
# 896101     Fantasy
# 896102   Adventure
# 896103   Animation
# 896104    Children
# 896105      Comedy
# 896106     Fantasy
# 896107   Adventure
# 896108   Animation
# 896109    Children
# 896110      Comedy
# 896111     Fantasy
# ...            ...
# 1238397  Adventure
# 1238398  Animation
# 1238399   Children
# 1238400     Comedy
# 1238401    Fantasy
# 1238402  Adventure
# 1238403  Animation
# 1238404   Children
# 1238405     Comedy
# 1238406    Fantasy
# 1238407  Adventure
# 1238408  Animation
# 1238409   Children
# 1238410     Comedy
# 1238411    Fantasy
# 1238412  Adventure
# 1238413  Animation
# 1238414   Children
# 1238415     Comedy
# 1238416    Fantasy
# 1238417  Adventure
# 1238418  Animation
# 1238419   Children
# 1238420     Comedy
# 1238421    Fantasy
# 1238422  Adventure
# 1238423  Animation
# 1238424   Children
# 1238425     Comedy
# 1238426    Fantasy
#
# [342345 rows x 7 columns]

# %%
movie_ratings.groupby(["genres"],as_index=False)["movieId"].count().sort_values(by="movieId", ascending=False)
# Out:
#                 genres   movieId
# 8                Drama  12191048
# 5               Comedy   9999184
# 1               Action   8214956
# 17            Thriller   7489628
# 2            Adventure   6452309
# 15             Romance   5078478
# 16              Sci-Fi   4740208
# 6                Crime   4631581
# 9              Fantasy   3118549
# 4             Children   2381124
# 14             Mystery   2210388
# 11              Horror   2070791
# 3            Animation   1803041
# 18                 War   1426112
# 13             Musical   1109674
# 12                IMAX   1102179
# 19             Western    542424
# 7          Documentary    345471
# 10           Film-Noir    272742
# 0   (no genres listed)     18389

# %%
genres_list=["Drama", "Comedy", "Action", "Thriller", "Adventure", "Romance",
            "Sci-Fi", "Crime", "Fantasy"]

# %%
movie_ratings = movie_ratings.loc[movie_ratings["genres"].isin(genres_list)]

# %%
movie_ratings.tail(10)
# Out:
#           userId  movieId  rating   timestamp rating_date rating_year  \
# 75198259  282374   166318     4.0  1479758063     2016-11        2016
# 75198260  282374   168674     1.5  1486168497     2017-02        2017
# 75198261  282374   168680     3.0  1486168702     2017-02        2017
# 75198262  282374   168680     3.0  1486168702     2017-02        2017
# 75198263  282374   168684     3.5  1486168812     2017-02        2017
# 75198265  282374   168686     3.0  1486168872     2017-02        2017
# 75198267  282374   168688     4.0  1486168898     2017-02        2017
# 75198268  282374   168694     4.0  1486169129     2017-02        2017
# 75198271  282403   167894     1.0  1524243885     2018-04        2018
# 75198272  282732   161572     3.5  1504408070     2017-09        2017
#
#              genres
# 75198259    Romance
# 75198260     Action
# 75198261     Comedy
# 75198262      Drama
# 75198263  Adventure
# 75198265      Drama
# 75198267     Comedy
# 75198268     Comedy
# 75198271     Action
# 75198272      Drama

# %% [markdown]
# ## Create time series of mean ratings vs. year and year-month

# %%
mean_ratings_year = movie_ratings.groupby(["rating_year", "genres"], as_index=False)["rating"].agg(np.mean)
# Out:
#   rating_year   genres  rating
# 0        1995   Comedy     3.0
# 1        1995    Crime     3.0
# 2        1995    Drama     4.0
# 3        1995  Fantasy     4.0
# 4        1995  Romance     4.0

# %%
mean_ratings_year.head(18)
# Out:
#    rating_year     genres    rating
# 0         1995     Comedy  3.000000
# 1         1995      Crime  3.000000
# 2         1995      Drama  4.000000
# 3         1995    Fantasy  4.000000
# 4         1995    Romance  4.000000
# 5         1995   Thriller  4.000000
# 6         1996     Action  3.443604
# 7         1996  Adventure  3.497114
# 8         1996     Comedy  3.425812
# 9         1996      Crime  3.629884
# 10        1996      Drama  3.715639
# 11        1996    Fantasy  3.489526
# 12        1996    Romance  3.610897
# 13        1996     Sci-Fi  3.431761
# 14        1996   Thriller  3.604584
# 15        1997     Action  3.548525
# 16        1997  Adventure  3.613980
# 17        1997     Comedy  3.495033

# %%
mean_ratings_year.shape
# Out:
# (213, 3)

# %%
mean_ratings_yearmonth = movie_ratings.groupby(["rating_date", "genres"], as_index=False)["rating"].agg(np.mean)

# %%
mean_ratings_yearmonth.rating_date.unique()  # 1997-09 to 2018-09 looks fine
# Out:
# array(['1995-01', '1996-01', '1996-02', '1996-03', '1996-04', '1996-05',
#        '1996-06', '1996-07', '1996-08', '1996-09', '1996-10', '1996-11',
#        '1996-12', '1997-01', '1997-02', '1997-03', '1997-04', '1997-05',
#        '1997-06', '1997-07', '1997-09', '1997-10', '1997-11', '1997-12',
#        '1998-01', '1998-02', '1998-03', '1998-04', '1998-05', '1998-06',
#        '1998-07', '1998-08', '1998-09', '1998-10', '1998-11', '1998-12',
#        '1999-01', '1999-02', '1999-03', '1999-04', '1999-05', '1999-06',
#        '1999-07', '1999-08', '1999-09', '1999-10', '1999-11', '1999-12',
#        '2000-01', '2000-02', '2000-03', '2000-04', '2000-05', '2000-06',
#        '2000-07', '2000-08', '2000-09', '2000-10', '2000-11', '2000-12',
#        '2001-01', '2001-02', '2001-03', '2001-04', '2001-05', '2001-06',
#        '2001-07', '2001-08', '2001-09', '2001-10', '2001-11', '2001-12',
#        '2002-01', '2002-02', '2002-03', '2002-04', '2002-05', '2002-06',
#        '2002-07', '2002-08', '2002-09', '2002-10', '2002-11', '2002-12',
#        '2003-01', '2003-02', '2003-03', '2003-04', '2003-05', '2003-06',
#        '2003-07', '2003-08', '2003-09', '2003-10', '2003-11', '2003-12',
#        '2004-01', '2004-02', '2004-03', '2004-04', '2004-05', '2004-06',
#        '2004-07', '2004-08', '2004-09', '2004-10', '2004-11', '2004-12',
#        '2005-01', '2005-02', '2005-03', '2005-04', '2005-05', '2005-06',
#        '2005-07', '2005-08', '2005-09', '2005-10', '2005-11', '2005-12',
#        '2006-01', '2006-02', '2006-03', '2006-04', '2006-05', '2006-06',
#        '2006-07', '2006-08', '2006-09', '2006-10', '2006-11', '2006-12',
#        '2007-01', '2007-02', '2007-03', '2007-04', '2007-05', '2007-06',
#        '2007-07', '2007-08', '2007-09', '2007-10', '2007-11', '2007-12',
#        '2008-01', '2008-02', '2008-03', '2008-04', '2008-05', '2008-06',
#        '2008-07', '2008-08', '2008-09', '2008-10', '2008-11', '2008-12',
#        '2009-01', '2009-02', '2009-03', '2009-04', '2009-05', '2009-06',
#        '2009-07', '2009-08', '2009-09', '2009-10', '2009-11', '2009-12',
#        '2010-01', '2010-02', '2010-03', '2010-04', '2010-05', '2010-06',
#        '2010-07', '2010-08', '2010-09', '2010-10', '2010-11', '2010-12',
#        '2011-01', '2011-02', '2011-03', '2011-04', '2011-05', '2011-06',
#        '2011-07', '2011-08', '2011-09', '2011-10', '2011-11', '2011-12',
#        '2012-01', '2012-02', '2012-03', '2012-04', '2012-05', '2012-06',
#        '2012-07', '2012-08', '2012-09', '2012-10', '2012-11', '2012-12',
#        '2013-01', '2013-02', '2013-03', '2013-04', '2013-05', '2013-06',
#        '2013-07', '2013-08', '2013-09', '2013-10', '2013-11', '2013-12',
#        '2014-01', '2014-02', '2014-03', '2014-04', '2014-05', '2014-06',
#        '2014-07', '2014-08', '2014-09', '2014-10', '2014-11', '2014-12',
#        '2015-01', '2015-02', '2015-03', '2015-04', '2015-05', '2015-06',
#        '2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12',
#        '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06',
#        '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12',
#        '2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06',
#        '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12',
#        '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06',
#        '2018-07', '2018-08', '2018-09'], dtype=object)

# %%
pd.to_datetime(mean_ratings_yearmonth["rating_date"], format="%Y-%m")
# Out:
# 0      1995-01-01
# 1      1995-01-01
# 2      1995-01-01
# 3      1995-01-01
# 4      1995-01-01
# 5      1995-01-01
# 6      1996-01-01
# 7      1996-01-01
# 8      1996-01-01
# 9      1996-01-01
# 10     1996-01-01
# 11     1996-01-01
# 12     1996-01-01
# 13     1996-01-01
# 14     1996-01-01
# 15     1996-02-01
# 16     1996-02-01
# 17     1996-02-01
# 18     1996-02-01
# 19     1996-02-01
# 20     1996-02-01
# 21     1996-02-01
# 22     1996-02-01
# 23     1996-02-01
# 24     1996-03-01
# 25     1996-03-01
# 26     1996-03-01
# 27     1996-03-01
# 28     1996-03-01
# 29     1996-03-01
#           ...
# 2424   2018-06-01
# 2425   2018-06-01
# 2426   2018-06-01
# 2427   2018-07-01
# 2428   2018-07-01
# 2429   2018-07-01
# 2430   2018-07-01
# 2431   2018-07-01
# 2432   2018-07-01
# 2433   2018-07-01
# 2434   2018-07-01
# 2435   2018-07-01
# 2436   2018-08-01
# 2437   2018-08-01
# 2438   2018-08-01
# 2439   2018-08-01
# 2440   2018-08-01
# 2441   2018-08-01
# 2442   2018-08-01
# 2443   2018-08-01
# 2444   2018-08-01
# 2445   2018-09-01
# 2446   2018-09-01
# 2447   2018-09-01
# 2448   2018-09-01
# 2449   2018-09-01
# 2450   2018-09-01
# 2451   2018-09-01
# 2452   2018-09-01
# 2453   2018-09-01
# Name: rating_date, Length: 2454, dtype: datetime64[ns]

# %%
## Only keep data between 1997 and 2018, and 1997-09 to 2018-09
mean_ratings_year = mean_ratings_year[mean_ratings_year["rating_year"]>"1996"]
mean_ratings_yearmonth = mean_ratings_yearmonth[mean_ratings_yearmonth["rating_date"]>='1997-09']

# %%
mean_ratings_yearmonth
# Out:
#      rating_date     genres    rating
# 177      1997-09     Action  3.497851
# 178      1997-09  Adventure  3.614968
# 179      1997-09     Comedy  3.547915
# 180      1997-09      Crime  3.722609
# 181      1997-09      Drama  3.706409
# 182      1997-09    Fantasy  3.587582
# 183      1997-09    Romance  3.645617
# 184      1997-09     Sci-Fi  3.594025
# 185      1997-09   Thriller  3.519164
# 186      1997-10     Action  3.505801
# 187      1997-10  Adventure  3.590452
# 188      1997-10     Comedy  3.468590
# 189      1997-10      Crime  3.695402
# 190      1997-10      Drama  3.665669
# 191      1997-10    Fantasy  3.527335
# 192      1997-10    Romance  3.598263
# 193      1997-10     Sci-Fi  3.597502
# 194      1997-10   Thriller  3.497024
# 195      1997-11     Action  3.411883
# 196      1997-11  Adventure  3.529372
# 197      1997-11     Comedy  3.466164
# 198      1997-11      Crime  3.669048
# 199      1997-11      Drama  3.664561
# 200      1997-11    Fantasy  3.543101
# 201      1997-11    Romance  3.590192
# 202      1997-11     Sci-Fi  3.513699
# 203      1997-11   Thriller  3.437533
# 204      1997-12     Action  3.424951
# 205      1997-12  Adventure  3.537306
# 206      1997-12     Comedy  3.461299
# ...          ...        ...       ...
# 2424     2018-06    Romance  3.598700
# 2425     2018-06     Sci-Fi  3.579804
# 2426     2018-06   Thriller  3.577264
# 2427     2018-07     Action  3.525763
# 2428     2018-07  Adventure  3.551949
# 2429     2018-07     Comedy  3.449227
# 2430     2018-07      Crime  3.724967
# 2431     2018-07      Drama  3.695628
# 2432     2018-07    Fantasy  3.498392
# 2433     2018-07    Romance  3.516012
# 2434     2018-07     Sci-Fi  3.568202
# 2435     2018-07   Thriller  3.563761
# 2436     2018-08     Action  3.507507
# 2437     2018-08  Adventure  3.557175
# 2438     2018-08     Comedy  3.414390
# 2439     2018-08      Crime  3.695318
# 2440     2018-08      Drama  3.662569
# 2441     2018-08    Fantasy  3.518765
# 2442     2018-08    Romance  3.518282
# 2443     2018-08     Sci-Fi  3.557812
# 2444     2018-08   Thriller  3.527500
# 2445     2018-09     Action  3.386111
# 2446     2018-09  Adventure  3.441283
# 2447     2018-09     Comedy  3.323526
# 2448     2018-09      Crime  3.630549
# 2449     2018-09      Drama  3.593279
# 2450     2018-09    Fantasy  3.414203
# 2451     2018-09    Romance  3.441228
# 2452     2018-09     Sci-Fi  3.423907
# 2453     2018-09   Thriller  3.438624
#
# [2277 rows x 3 columns]

# %%
# do similar things on standard deviation
std_ratings_year = movie_ratings.groupby(["rating_year", "genres"], as_index=False)["rating"].agg(np.std, ddof=1)
std_ratings_year = std_ratings_year[std_ratings_year["rating_year"]>"1996"]
std_ratings_yearmonth = movie_ratings.groupby(["rating_date", "genres"], as_index=False)["rating"].agg(np.std, ddof=1)
std_ratings_yearmonth = std_ratings_yearmonth[std_ratings_yearmonth["rating_date"]>="1997-09"]

# %%
std_ratings_year.rename(columns={"rating":"rating_std"}, inplace=True)
std_ratings_yearmonth.rename(columns={"rating":"rating_std"}, inplace=True)

# %% [markdown]
# ## Store processed time series data to csv

# %%
mean_ratings_year.to_csv("./processed_data/mean_ratings_year.csv", header=True)
mean_ratings_yearmonth.to_csv("./processed_data/mean_ratings_yearmonth.csv", header=True)
std_ratings_year.to_csv("./processed_data/std_ratings_year.csv", header=True)
std_ratings_yearmonth.to_csv("./processed_data/std_ratings_yearmonth.csv", header=True)

# %%
## read data
mean_ratings_year = pd.read_csv("./processed_data/mean_ratings_year.csv", index_col=0)
mean_ratings_yearmonth = pd.read_csv("./processed_data/mean_ratings_yearmonth.csv", index_col=0)
std_ratings_year = pd.read_csv("./processed_data/std_ratings_year.csv", index_col=0)
std_ratings_year = pd.read_csv("./processed_data/std_ratings_yearmonth.csv", index_col=0)

# %% [markdown]
# ## EDA

# %%
mean_ratings_year = pd.pivot_table(mean_ratings_year, values='rating', index=['rating_year'], columns=['genres'])
mean_ratings_year
# Out:
# genres         Action  Adventure    Comedy     Crime     Drama   Fantasy  \
# rating_year
# 1997         3.548525   3.613980  3.495033  3.730365  3.723624  3.564130
# 1998         3.449360   3.513609  3.444061  3.637904  3.681496  3.444800
# 1999         3.456230   3.521396  3.548891  3.760173  3.761720  3.540008
# 2000         3.478141   3.555149  3.505346  3.724306  3.731078  3.505363
# 2001         3.466287   3.538901  3.452050  3.695761  3.690312  3.501080
# 2002         3.402068   3.496604  3.390198  3.652576  3.643979  3.496089
# 2003         3.359482   3.479238  3.390235  3.607162  3.620900  3.504180
# 2004         3.323862   3.419152  3.335580  3.557621  3.587004  3.457905
# 2005         3.323825   3.405254  3.327510  3.583837  3.595053  3.438771
# 2006         3.363714   3.433966  3.351730  3.614240  3.614317  3.459418
# 2007         3.382145   3.435030  3.339137  3.632095  3.618656  3.453422
# 2008         3.475813   3.489213  3.406240  3.712816  3.664359  3.501539
# 2009         3.434286   3.462095  3.367590  3.666854  3.638328  3.477095
# 2010         3.470126   3.499578  3.391891  3.701197  3.648083  3.492930
# 2011         3.498496   3.515737  3.415441  3.719788  3.670989  3.525405
# 2012         3.558395   3.580692  3.460730  3.747683  3.709767  3.572383
# 2013         3.598565   3.629682  3.501340  3.772147  3.743335  3.618523
# 2014         3.548827   3.584405  3.476961  3.746445  3.723375  3.579551
# 2015         3.542914   3.567872  3.430412  3.743587  3.707542  3.544758
# 2016         3.503665   3.537111  3.417876  3.700546  3.679437  3.509339
# 2017         3.513110   3.543652  3.435595  3.715893  3.692530  3.528070
# 2018         3.517087   3.552170  3.437394  3.717671  3.692075  3.520461
#
# genres        Romance    Sci-Fi  Thriller
# rating_year
# 1997         3.623943  3.626507  3.530168
# 1998         3.637055  3.440529  3.461829
# 1999         3.691495  3.447996  3.555144
# 2000         3.638275  3.452382  3.513800
# 2001         3.589955  3.409064  3.493300
# 2002         3.535497  3.388271  3.466833
# 2003         3.508837  3.351178  3.433568
# 2004         3.441248  3.300873  3.390562
# 2005         3.422432  3.302825  3.399659
# 2006         3.460963  3.343404  3.429720
# 2007         3.459207  3.379564  3.464274
# 2008         3.515291  3.457168  3.528401
# 2009         3.495884  3.427226  3.474322
# 2010         3.497337  3.473778  3.502073
# 2011         3.522332  3.497571  3.542819
# 2012         3.578071  3.553666  3.594763
# 2013         3.612121  3.612301  3.631873
# 2014         3.587839  3.569900  3.598008
# 2015         3.526737  3.583713  3.584941
# 2016         3.507312  3.540580  3.546014
# 2017         3.529560  3.555700  3.558469
# 2018         3.539458  3.554118  3.557953

# %%
mean_ratings_year.corr()
# Out:
# genres       Action  Adventure    Comedy     Crime     Drama   Fantasy  \
# genres
# Action     1.000000   0.938348  0.738907  0.927277  0.844652  0.856183
# Adventure  0.938348   1.000000  0.843704  0.865885  0.890492  0.887435
# Comedy     0.738907   0.843704  1.000000  0.825526  0.971719  0.742580
# Crime      0.927277   0.865885  0.825526  1.000000  0.913659  0.845309
# Drama      0.844652   0.890492  0.971719  0.913659  1.000000  0.791496
# Fantasy    0.856183   0.887435  0.742580  0.845309  0.791496  1.000000
# Romance    0.598774   0.734348  0.949700  0.680846  0.890137  0.568263
# Sci-Fi     0.968314   0.910684  0.672922  0.868166  0.785433  0.831855
# Thriller   0.952664   0.872797  0.735786  0.953339  0.851071  0.890495
#
# genres      Romance    Sci-Fi  Thriller
# genres
# Action     0.598774  0.968314  0.952664
# Adventure  0.734348  0.910684  0.872797
# Comedy     0.949700  0.672922  0.735786
# Crime      0.680846  0.868166  0.953339
# Drama      0.890137  0.785433  0.851071
# Fantasy    0.568263  0.831855  0.890495
# Romance    1.000000  0.516436  0.564596
# Sci-Fi     0.516436  1.000000  0.913595
# Thriller   0.564596  0.913595  1.000000

# %%
mean_ratings_yearmonth = pd.pivot_table(mean_ratings_yearmonth, values='rating', index=['rating_date'], columns=['genres'])
mean_ratings_yearmonth
# Out:
# genres         Action  Adventure    Comedy     Crime     Drama   Fantasy  \
# rating_date
# 1997-09      3.497851   3.614968  3.547915  3.722609  3.706409  3.587582
# 1997-10      3.505801   3.590452  3.468590  3.695402  3.665669  3.527335
# 1997-11      3.411883   3.529372  3.466164  3.669048  3.664561  3.543101
# 1997-12      3.424951   3.537306  3.461299  3.664982  3.640967  3.507917
# 1998-01      3.369930   3.474170  3.345554  3.540208  3.507089  3.402778
# 1998-02      3.357514   3.438235  3.326405  3.564177  3.533341  3.362241
# 1998-03      3.402358   3.532372  3.442641  3.626349  3.688915  3.465441
# 1998-04      3.426793   3.566129  3.465083  3.672682  3.679584  3.532730
# 1998-05      3.320755   3.443912  3.486557  3.648716  3.650956  3.425308
# 1998-06      3.345369   3.452720  3.417350  3.566909  3.612936  3.452846
# 1998-07      3.504230   3.559545  3.467730  3.691262  3.745611  3.462553
# 1998-08      3.483847   3.502962  3.466680  3.640656  3.740033  3.430331
# 1998-09      3.433527   3.458170  3.430167  3.612058  3.696345  3.434252
# 1998-10      3.435795   3.449730  3.446850  3.620912  3.663827  3.399254
# 1998-11      3.550754   3.572581  3.498810  3.665731  3.740075  3.483523
# 1998-12      3.449791   3.507715  3.454058  3.633959  3.701279  3.437739
# 1999-01      3.364937   3.417390  3.406956  3.560445  3.649649  3.337070
# 1999-02      3.529689   3.585305  3.563652  3.755530  3.778339  3.555968
# 1999-03      3.430924   3.504554  3.507728  3.600416  3.664149  3.420827
# 1999-04      3.498013   3.525429  3.524830  3.628692  3.703465  3.444033
# 1999-05      3.408454   3.471391  3.447278  3.644240  3.673183  3.434615
# 1999-06      3.447159   3.476341  3.471971  3.653012  3.678268  3.419732
# 1999-07      3.499655   3.540576  3.420116  3.611287  3.607959  3.434555
# 1999-08      3.365481   3.452344  3.488805  3.570466  3.562807  3.456107
# 1999-09      3.398578   3.517391  3.564590  3.879313  3.789847  3.520704
# 1999-10      3.383792   3.465816  3.602530  3.835970  3.790762  3.571595
# 1999-11      3.441994   3.490901  3.542078  3.746500  3.759018  3.545929
# 1999-12      3.511414   3.573238  3.528302  3.730678  3.755751  3.545280
# 2000-01      3.475572   3.542104  3.540197  3.745160  3.751939  3.563095
# 2000-02      3.507041   3.566630  3.535532  3.745809  3.771578  3.539613
# ...               ...        ...       ...       ...       ...       ...
# 2016-04      3.539357   3.563743  3.466066  3.740678  3.729399  3.525008
# 2016-05      3.477226   3.499867  3.389529  3.677861  3.657655  3.477246
# 2016-06      3.410983   3.457218  3.313974  3.603492  3.600851  3.414914
# 2016-07      3.525732   3.539204  3.424735  3.743239  3.689980  3.493356
# 2016-08      3.519189   3.562946  3.461761  3.703753  3.709911  3.538232
# 2016-09      3.562515   3.600526  3.462260  3.745729  3.714469  3.556393
# 2016-10      3.545276   3.583311  3.451222  3.722063  3.691483  3.570377
# 2016-11      3.538691   3.582603  3.482138  3.746985  3.733587  3.568991
# 2016-12      3.544756   3.584672  3.455162  3.733361  3.719716  3.575927
# 2017-01      3.513715   3.538415  3.426611  3.735037  3.702274  3.518555
# 2017-02      3.505714   3.540750  3.423554  3.706473  3.667190  3.536007
# 2017-03      3.496040   3.533602  3.409973  3.702157  3.701487  3.519584
# 2017-04      3.566303   3.578632  3.492929  3.773896  3.734281  3.574938
# 2017-05      3.520493   3.564351  3.497929  3.727054  3.727615  3.556673
# 2017-06      3.497767   3.540228  3.412150  3.675368  3.655998  3.530789
# 2017-07      3.527530   3.548829  3.439462  3.724349  3.698711  3.518430
# 2017-08      3.553038   3.578481  3.488868  3.758938  3.730494  3.550989
# 2017-09      3.468322   3.504589  3.374895  3.666594  3.631583  3.479102
# 2017-10      3.535125   3.560257  3.448002  3.735322  3.719179  3.535144
# 2017-11      3.463148   3.511835  3.423793  3.679975  3.666762  3.502596
# 2017-12      3.504722   3.516782  3.375124  3.694074  3.658697  3.506119
# 2018-01      3.502844   3.529790  3.435513  3.710104  3.688107  3.518208
# 2018-02      3.645307   3.673617  3.527134  3.811471  3.777530  3.649459
# 2018-03      3.522142   3.554552  3.444925  3.726866  3.690900  3.531543
# 2018-04      3.502131   3.535394  3.431296  3.732222  3.707615  3.510672
# 2018-05      3.517145   3.544951  3.438787  3.703371  3.699815  3.494306
# 2018-06      3.545266   3.575223  3.467511  3.724195  3.716126  3.531271
# 2018-07      3.525763   3.551949  3.449227  3.724967  3.695628  3.498392
# 2018-08      3.507507   3.557175  3.414390  3.695318  3.662569  3.518765
# 2018-09      3.386111   3.441283  3.323526  3.630549  3.593279  3.414203
#
# genres        Romance    Sci-Fi  Thriller
# rating_date
# 1997-09      3.645617  3.594025  3.519164
# 1997-10      3.598263  3.597502  3.497024
# 1997-11      3.590192  3.513699  3.437533
# 1997-12      3.553970  3.518480  3.425153
# 1998-01      3.496704  3.455460  3.376575
# 1998-02      3.482628  3.409192  3.370228
# 1998-03      3.652230  3.499450  3.432021
# 1998-04      3.646277  3.471719  3.472904
# 1998-05      3.684980  3.418219  3.409234
# 1998-06      3.611829  3.473947  3.418215
# 1998-07      3.675951  3.459076  3.512768
# 1998-08      3.666220  3.390031  3.443899
# 1998-09      3.643009  3.405195  3.467028
# 1998-10      3.590685  3.358308  3.454378
# 1998-11      3.683852  3.519759  3.553475
# 1998-12      3.658864  3.417507  3.473779
# 1999-01      3.586172  3.330390  3.401651
# 1999-02      3.726914  3.452601  3.592719
# 1999-03      3.671671  3.395819  3.522199
# 1999-04      3.642880  3.498528  3.550121
# 1999-05      3.594688  3.388446  3.514615
# 1999-06      3.643736  3.441428  3.500488
# 1999-07      3.546846  3.511051  3.494857
# 1999-08      3.551288  3.373225  3.383955
# 1999-09      3.715700  3.428222  3.567486
# 1999-10      3.727272  3.407132  3.586474
# 1999-11      3.692049  3.429818  3.548423
# 1999-12      3.673087  3.488260  3.554519
# 2000-01      3.665219  3.460289  3.541970
# 2000-02      3.683712  3.490521  3.549743
# ...               ...       ...       ...
# 2016-04      3.558709  3.576299  3.590962
# 2016-05      3.469744  3.518069  3.527214
# 2016-06      3.431732  3.466069  3.436902
# 2016-07      3.502559  3.556852  3.590165
# 2016-08      3.553082  3.546340  3.556452
# 2016-09      3.552438  3.574589  3.577373
# 2016-10      3.544004  3.565250  3.556085
# 2016-11      3.584704  3.581972  3.597045
# 2016-12      3.533745  3.592510  3.593228
# 2017-01      3.505018  3.553834  3.571180
# 2017-02      3.502946  3.540829  3.537317
# 2017-03      3.529507  3.549991  3.542076
# 2017-04      3.559392  3.608728  3.629932
# 2017-05      3.597365  3.574270  3.574344
# 2017-06      3.526234  3.549587  3.533109
# 2017-07      3.523097  3.574059  3.568546
# 2017-08      3.575537  3.583856  3.602930
# 2017-09      3.467941  3.509942  3.497341
# 2017-10      3.562841  3.561177  3.571202
# 2017-11      3.507375  3.508574  3.508615
# 2017-12      3.486163  3.543163  3.561211
# 2018-01      3.530604  3.536938  3.556446
# 2018-02      3.625881  3.662760  3.680563
# 2018-03      3.542247  3.557686  3.562720
# 2018-04      3.537395  3.552590  3.558077
# 2018-05      3.546896  3.546816  3.563887
# 2018-06      3.598700  3.579804  3.577264
# 2018-07      3.516012  3.568202  3.563761
# 2018-08      3.518282  3.557812  3.527500
# 2018-09      3.441228  3.423907  3.438624
#
# [253 rows x 9 columns]

# %%
mean_ratings_yearmonth.corr()
# Out:
# genres       Action  Adventure    Comedy     Crime     Drama   Fantasy  \
# genres
# Action     1.000000   0.923204  0.729434  0.882610  0.814628  0.784651
# Adventure  0.923204   1.000000  0.830091  0.835145  0.842614  0.864805
# Comedy     0.729434   0.830091  1.000000  0.779892  0.897575  0.722371
# Crime      0.882610   0.835145  0.779892  1.000000  0.888357  0.796705
# Drama      0.814628   0.842614  0.897575  0.888357  1.000000  0.758573
# Fantasy    0.784651   0.864805  0.722371  0.796705  0.758573  1.000000
# Romance    0.596072   0.721450  0.926935  0.649897  0.844848  0.566995
# Sci-Fi     0.938310   0.875236  0.655691  0.824027  0.721262  0.739813
# Thriller   0.952381   0.876558  0.748910  0.928210  0.855821  0.817106
#
# genres      Romance    Sci-Fi  Thriller
# genres
# Action     0.596072  0.938310  0.952381
# Adventure  0.721450  0.875236  0.876558
# Comedy     0.926935  0.655691  0.748910
# Crime      0.649897  0.824027  0.928210
# Drama      0.844848  0.721262  0.855821
# Fantasy    0.566995  0.739813  0.817106
# Romance    1.000000  0.513609  0.602561
# Sci-Fi     0.513609  1.000000  0.902010
# Thriller   0.602561  0.902010  1.000000

# %%
std_ratings_year = pd.pivot_table(std_ratings_year, values='rating_std', index=['rating_year'], columns=['genres'])
std_ratings_year
# Out:
# genres         Action  Adventure    Comedy     Crime     Drama   Fantasy  \
# rating_year
# 1997         0.991613   0.986052  1.026341  1.006027  0.978439  0.999549
# 1998         1.133555   1.114580  1.142351  1.098438  1.080172  1.140301
# 1999         1.152192   1.140374  1.127373  1.084896  1.061780  1.133625
# 2000         1.138157   1.118413  1.131405  1.082488  1.059834  1.142221
# 2001         1.131396   1.114951  1.127569  1.072367  1.060848  1.132867
# 2002         1.125330   1.115939  1.127651  1.073221  1.056151  1.137522
# 2003         1.085659   1.072834  1.080409  1.011525  0.998215  1.092613
# 2004         1.057050   1.051818  1.056194  0.987601  0.964640  1.065470
# 2005         1.062905   1.053993  1.059537  0.986384  0.964872  1.069447
# 2006         1.057000   1.045436  1.054068  0.982168  0.961043  1.057030
# 2007         1.053476   1.040056  1.058480  0.982902  0.970908  1.051740
# 2008         1.021549   1.018731  1.042035  0.952225  0.959833  1.032099
# 2009         1.049781   1.046845  1.067617  0.977701  0.977027  1.057061
# 2010         1.049964   1.042989  1.072883  0.969462  0.978124  1.065761
# 2011         1.036163   1.038183  1.062572  0.962712  0.966610  1.056299
# 2012         1.022638   1.033230  1.059570  0.950762  0.954060  1.055128
# 2013         1.010027   1.013378  1.051354  0.951262  0.949898  1.036484
# 2014         1.039487   1.040126  1.079621  0.982775  0.975716  1.065349
# 2015         1.095520   1.105391  1.122692  1.024130  1.020610  1.141507
# 2016         1.109992   1.116829  1.129913  1.043335  1.034720  1.148383
# 2017         1.096645   1.104878  1.114811  1.031337  1.021525  1.125864
# 2018         1.099027   1.106353  1.113703  1.030867  1.022296  1.136827
#
# genres        Romance    Sci-Fi  Thriller
# rating_year
# 1997         0.980139  1.027747  0.980717
# 1998         1.086116  1.157638  1.119975
# 1999         1.081156  1.164124  1.118220
# 2000         1.082141  1.156197  1.108970
# 2001         1.087148  1.150686  1.103629
# 2002         1.091127  1.141546  1.094946
# 2003         1.042634  1.102371  1.047839
# 2004         1.022980  1.075672  1.012150
# 2005         1.030425  1.080603  1.020510
# 2006         1.021201  1.072239  1.020158
# 2007         1.024170  1.065306  1.018396
# 2008         1.011166  1.039322  0.994908
# 2009         1.032089  1.073287  1.023822
# 2010         1.028681  1.070623  1.024368
# 2011         1.024345  1.044982  1.006066
# 2012         1.012872  1.038122  0.991405
# 2013         1.011066  1.014108  0.978324
# 2014         1.039380  1.040044  1.015735
# 2015         1.099272  1.091354  1.057771
# 2016         1.108154  1.108248  1.078547
# 2017         1.094323  1.092245  1.060172
# 2018         1.093194  1.101836  1.064888

# %%
std_ratings_yearmonth = pd.pivot_table(std_ratings_yearmonth, values='rating_std', index=['rating_date'], columns=['genres'])
std_ratings_yearmonth
# Out:
# genres         Action  Adventure    Comedy     Crime     Drama   Fantasy  \
# rating_date
# 1997-09      1.106538   1.092228  1.090593  1.064400  1.069022  1.075551
# 1997-10      1.079621   1.072075  1.105809  1.042518  1.047145  1.098481
# 1997-11      1.110505   1.105470  1.132242  1.097050  1.072954  1.120343
# 1997-12      1.118911   1.102524  1.128847  1.098946  1.077308  1.116165
# 1998-01      1.125609   1.118400  1.165350  1.130655  1.134554  1.129559
# 1998-02      1.140692   1.137107  1.163709  1.130277  1.115039  1.203879
# 1998-03      1.124581   1.099226  1.145219  1.105604  1.079239  1.171270
# 1998-04      1.149184   1.138473  1.174478  1.103944  1.117697  1.193905
# 1998-05      1.180462   1.130976  1.163081  1.114928  1.073599  1.151450
# 1998-06      1.196054   1.205149  1.191630  1.176887  1.137446  1.200777
# 1998-07      1.114003   1.091118  1.127968  1.064639  1.038032  1.118897
# 1998-08      1.125885   1.108232  1.120916  1.080796  1.061150  1.133904
# 1998-09      1.135999   1.100842  1.100689  1.066562  1.061339  1.103009
# 1998-10      1.108496   1.087177  1.132634  1.067026  1.071821  1.138438
# 1998-11      1.148320   1.134782  1.126960  1.089650  1.054774  1.120769
# 1998-12      1.140506   1.122313  1.155246  1.139447  1.083642  1.143435
# 1999-01      1.113904   1.099074  1.127283  1.108647  1.042747  1.099785
# 1999-02      1.063680   1.065518  1.092442  1.042093  0.999697  1.026621
# 1999-03      1.174700   1.144939  1.127855  1.131799  1.075350  1.117942
# 1999-04      1.089957   1.102598  1.110770  1.104358  1.041801  1.135816
# 1999-05      1.149694   1.113678  1.093993  1.090500  1.019536  1.111713
# 1999-06      1.112874   1.115625  1.094210  1.039351  1.008228  1.152510
# 1999-07      1.128681   1.110489  1.142248  1.058780  1.068869  1.119046
# 1999-08      1.170292   1.160471  1.160440  1.177631  1.139243  1.151379
# 1999-09      1.190434   1.174199  1.144432  1.053544  1.072448  1.173764
# 1999-10      1.170261   1.167422  1.120780  1.070950  1.059733  1.137511
# 1999-11      1.135593   1.131015  1.115146  1.072687  1.046751  1.126377
# 1999-12      1.152069   1.132439  1.137865  1.097133  1.073973  1.135824
# 2000-01      1.143737   1.124298  1.135060  1.097490  1.069916  1.123113
# 2000-02      1.124759   1.117694  1.122291  1.073742  1.046098  1.126386
# ...               ...        ...       ...       ...       ...       ...
# 2016-04      1.092859   1.100691  1.101660  1.008298  0.991613  1.136232
# 2016-05      1.137144   1.154650  1.149901  1.068797  1.054824  1.184070
# 2016-06      1.144863   1.138860  1.179388  1.109630  1.094283  1.172696
# 2016-07      1.144900   1.160043  1.170972  1.063589  1.076396  1.197509
# 2016-08      1.079976   1.087230  1.097735  1.020652  0.991620  1.120802
# 2016-09      1.075237   1.082039  1.107651  1.003602  1.019041  1.127926
# 2016-10      1.082745   1.083683  1.104355  1.026499  1.021604  1.110475
# 2016-11      1.063438   1.068007  1.078280  0.997447  0.973695  1.086577
# 2016-12      1.113979   1.115852  1.138275  1.037780  1.027893  1.135488
# 2017-01      1.121770   1.125867  1.123824  1.049859  1.034245  1.139107
# 2017-02      1.073357   1.082632  1.104301  1.013276  1.013028  1.095036
# 2017-03      1.117312   1.118630  1.145936  1.058410  1.031510  1.144090
# 2017-04      1.086730   1.097574  1.112298  1.018716  1.023578  1.112774
# 2017-05      1.054774   1.066750  1.063720  0.993095  0.971157  1.083686
# 2017-06      1.070968   1.082289  1.097130  1.014346  1.007722  1.096819
# 2017-07      1.085767   1.098061  1.099580  1.024749  1.009049  1.128140
# 2017-08      1.059798   1.068954  1.061097  0.994475  0.988392  1.090826
# 2017-09      1.130953   1.141434  1.154670  1.063223  1.064281  1.178387
# 2017-10      1.084683   1.095334  1.111607  1.016633  1.008614  1.123129
# 2017-11      1.154502   1.152882  1.140951  1.058652  1.043502  1.172416
# 2017-12      1.127517   1.134787  1.165385  1.071823  1.073735  1.155007
# 2018-01      1.074224   1.080360  1.075244  1.023357  1.014056  1.102590
# 2018-02      1.086167   1.090550  1.131283  1.018526  1.017900  1.129394
# 2018-03      1.080956   1.090380  1.105102  1.021908  1.019073  1.119707
# 2018-04      1.133400   1.137399  1.140285  1.053740  1.041236  1.165587
# 2018-05      1.074215   1.100817  1.106356  1.005009  1.008313  1.145055
# 2018-06      1.074773   1.086513  1.095079  1.005633  0.997216  1.111636
# 2018-07      1.103978   1.112029  1.100342  1.024883  1.010143  1.144629
# 2018-08      1.092924   1.089332  1.094447  1.027308  1.008046  1.114445
# 2018-09      1.162021   1.168337  1.178207  1.088870  1.076197  1.200362
#
# genres        Romance    Sci-Fi  Thriller
# rating_date
# 1997-09      1.072771  1.105557  1.090471
# 1997-10      1.063437  1.074285  1.064050
# 1997-11      1.088941  1.131036  1.098396
# 1997-12      1.089283  1.153341  1.119209
# 1998-01      1.124248  1.153509  1.115195
# 1998-02      1.137214  1.168365  1.124234
# 1998-03      1.081570  1.133379  1.118575
# 1998-04      1.131556  1.169020  1.132944
# 1998-05      1.072137  1.143248  1.123223
# 1998-06      1.124121  1.208209  1.161233
# 1998-07      1.060257  1.145419  1.106504
# 1998-08      1.064682  1.151451  1.118417
# 1998-09      1.062434  1.161569  1.085613
# 1998-10      1.102554  1.163392  1.111026
# 1998-11      1.097260  1.162804  1.120310
# 1998-12      1.067301  1.173001  1.142679
# 1999-01      1.075256  1.132962  1.086084
# 1999-02      1.024516  1.124970  1.047936
# 1999-03      1.110510  1.214691  1.128407
# 1999-04      1.065418  1.115932  1.084929
# 1999-05      1.014376  1.156547  1.106149
# 1999-06      1.053863  1.118204  1.073237
# 1999-07      1.109810  1.152719  1.099000
# 1999-08      1.132436  1.169248  1.161989
# 1999-09      1.097530  1.216911  1.156456
# 1999-10      1.085106  1.174468  1.135044
# 1999-11      1.067507  1.150785  1.105318
# 1999-12      1.085747  1.163834  1.115511
# 2000-01      1.089485  1.159664  1.118937
# 2000-02      1.068761  1.136020  1.098743
# ...               ...       ...       ...
# 2016-04      1.071172  1.088815  1.053429
# 2016-05      1.132143  1.126010  1.099713
# 2016-06      1.137922  1.138446  1.137058
# 2016-07      1.145599  1.147103  1.109331
# 2016-08      1.070463  1.071634  1.035490
# 2016-09      1.095034  1.087646  1.058297
# 2016-10      1.083827  1.096496  1.077301
# 2016-11      1.046558  1.064684  1.019359
# 2016-12      1.125103  1.099413  1.076128
# 2017-01      1.114267  1.111837  1.073676
# 2017-02      1.084132  1.072559  1.031765
# 2017-03      1.108374  1.104786  1.086053
# 2017-04      1.094125  1.073128  1.056591
# 2017-05      1.034141  1.052872  1.018422
# 2017-06      1.069164  1.073611  1.032142
# 2017-07      1.102450  1.085392  1.053829
# 2017-08      1.039014  1.067747  1.029888
# 2017-09      1.133611  1.120495  1.102087
# 2017-10      1.085151  1.086214  1.052054
# 2017-11      1.120817  1.145459  1.103664
# 2017-12      1.149436  1.122620  1.092078
# 2018-01      1.061855  1.083935  1.051954
# 2018-02      1.103121  1.089043  1.049398
# 2018-03      1.081539  1.084235  1.049722
# 2018-04      1.115869  1.133279  1.097628
# 2018-05      1.096488  1.098942  1.039068
# 2018-06      1.055502  1.078392  1.037479
# 2018-07      1.089325  1.097307  1.067325
# 2018-08      1.075828  1.096062  1.064451
# 2018-09      1.158442  1.148581  1.111611
#
# [253 rows x 9 columns]

# %%
ax = mean_ratings_year.plot(kind="line", lw=3, figsize=(15,12), fontsize=18)
ax.set_xlabel("Year", fontsize=18)
ax.set_ylabel("Mean Rating", fontsize=18)
ax.legend(fontsize=18)

plt.tight_layout()
plt.savefig("Temporal_Yearly.pdf")

# %%
ax = mean_ratings_yearmonth.plot(kind="line", lw=3, figsize=(15,12), fontsize=18)
ax.set_xlabel("Year-Month", fontsize=18)
ax.set_ylabel("Mean Rating", fontsize=18)
ax.legend(bbox_to_anchor=(0.28,0.65), fontsize=18)

plt.tight_layout()
plt.savefig("Temporal_Monthly.pdf")

# %%
ax = mean_ratings_yearmonth.pct_change().plot(kind="line", lw=3, figsize=(15,12), fontsize=18)
ax.set_xlabel("Year-Month", fontsize=18)
ax.set_ylabel("Pct Change in Mean Rating", fontsize=18)
ax.legend(fontsize=18)

# %% [markdown]
# ### Visualizing recent five years  (each dot being a movie)

# %%
ratings_YearGenreMovieId = movie_ratings.groupby(["movieId", "rating_year", "genres"], as_index=False).agg(np.mean)

# %%
ratings_YearGenreMovieId.head()  # here the average is taken wrt users, for each movie in a given genre and year
# Out:
#    movieId rating_year     genres         userId    rating     timestamp
# 0        1        1996  Adventure  142122.867644  4.119812  8.404510e+08
# 1        1        1996     Comedy  142122.867644  4.119812  8.404510e+08
# 2        1        1996    Fantasy  142122.867644  4.119812  8.404510e+08
# 3        1        1997  Adventure  139563.453197  3.868780  8.614428e+08
# 4        1        1997     Comedy  139563.453197  3.868780  8.614428e+08

# %%
ratings_13to17 = ratings_YearGenreMovieId.loc[ratings_YearGenreMovieId.rating_year.isin(['2013','2014','2015','2016','2017'])]

# %%
ratings_13to17.head()
# Out:
#     movieId rating_year     genres         userId    rating     timestamp
# 51        1        2013  Adventure  148034.100612  3.951444  1.371758e+09
# 52        1        2013     Comedy  148034.100612  3.951444  1.371758e+09
# 53        1        2013    Fantasy  148034.100612  3.951444  1.371758e+09
# 54        1        2014  Adventure  135291.418322  3.960265  1.404724e+09
# 55        1        2014     Comedy  135291.418322  3.960265  1.404724e+09

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x="rating_year", y="rating", hue="genres", data=ratings_13to17)
plt.xlabel("Year", fontsize=20)
plt.ylabel("Mean Rating", fontsize=20)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(bbox_to_anchor=(1.2,0.7), fontsize=16)

plt.tight_layout()
plt.savefig("YearlyPlot.pdf")

# %% [markdown]
# ### Visualizing each month in 2017 (each dot being a movie)

# %%
ratings_MonthGenreMovieId = movie_ratings.groupby(["movieId", "rating_date", "genres"], as_index=False).agg(np.mean)

# %%
ratings_MonthGenreMovieId.head()  # here the average is taken wrt users, for each movie in a given genre and year-month
# Out:
#    movieId rating_date     genres         userId    rating     timestamp
# 0        1     1996-01  Adventure  212699.000000  4.000000  8.229166e+08
# 1        1     1996-01     Comedy  212699.000000  4.000000  8.229166e+08
# 2        1     1996-01    Fantasy  212699.000000  4.000000  8.229166e+08
# 3        1     1996-02  Adventure  143793.058824  4.529412  8.244260e+08
# 4        1     1996-02     Comedy  143793.058824  4.529412  8.244260e+08

# %%
ratings_2017 = ratings_MonthGenreMovieId.loc[ratings_MonthGenreMovieId.rating_date.isin(['2017-01',
                                                                                         '2017-02','2017-03',
                                                                                         '2017-04','2017-05',
                                                                                        '2017-06','2017-07',
                                                                                        '2017-08','2017-09',
                                                                                        '2017-10','2017-11',
                                                                                        '2017-12'])]

# %%
ratings_2017["Month"] = ratings_2017["rating_date"].apply(lambda x: x[-2:])
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x='Month', y="rating", hue="genres", data=ratings_2017)
plt.xlabel("Month of Year 2017", fontsize=20)
plt.ylabel("Mean Rating", fontsize=20)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(bbox_to_anchor=(1.2,0.7), fontsize=16)

plt.tight_layout()
plt.savefig("MonthlyPlot.pdf")

# %% [markdown]
# ### Visualizing recent five years  (each dot being a consumer)

# %%
ratings_YearGenreUserId = movie_ratings.groupby(["userId", "rating_year", "genres"], as_index=False).agg(np.mean)

# %%
ratings_YearGenreUserId.head(20)
# Out:
#     userId rating_year     genres      movieId    rating     timestamp
# 0        1        2009     Action  2823.750000  2.875000  1.256677e+09
# 1        1        2009  Adventure  1591.000000  1.500000  1.256677e+09
# 2        1        2009     Comedy  2050.333333  3.750000  1.256677e+09
# 3        1        2009      Crime  3439.500000  3.000000  1.256677e+09
# 4        1        2009      Drama  2327.500000  3.666667  1.256677e+09
# 5        1        2009    Fantasy  2134.000000  4.500000  1.256677e+09
# 6        1        2009    Romance  2575.000000  4.000000  1.256677e+09
# 7        1        2009     Sci-Fi  2637.500000  2.750000  1.256677e+09
# 8        1        2009   Thriller  2458.142857  2.642857  1.256677e+09
# 9        2        2007     Action   509.500000  3.500000  1.192914e+09
# 10       2        2007  Adventure   509.500000  3.500000  1.192914e+09
# 11       2        2007     Comedy  2207.666667  3.611111  1.192914e+09
# 12       2        2007      Crime   170.000000  3.500000  1.192914e+09
# 13       2        2007      Drama  1860.125000  3.812500  1.192914e+09
# 14       2        2007    Romance  1625.200000  3.700000  1.192914e+09
# 15       2        2007     Sci-Fi   849.000000  3.500000  1.192914e+09
# 16       2        2007   Thriller  1242.000000  3.500000  1.192914e+09
# 17       3        1999     Action  2028.000000  5.000000  9.451416e+08
# 18       3        1999  Adventure   828.000000  4.000000  9.451416e+08
# 19       3        1999     Comedy  1573.000000  3.500000  9.451415e+08

# %%
ratings_13to17_users = ratings_YearGenreUserId.loc[ratings_YearGenreUserId.rating_year.isin(['2013','2014','2015','2016','2017'])]

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x="rating_year", y="rating", hue="genres", data=ratings_13to17_users)
plt.xlabel("Year", fontsize=20)
plt.ylabel("Mean Rating", fontsize=20)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(bbox_to_anchor=(1.2,0.7), fontsize=16)

plt.tight_layout()
plt.savefig("YearlyPlot_Users.pdf")

# %% [markdown]
# ### Visualizing each month in 2017 (each dot being a consumer)

# %%
ratings_MonthGenreUserId = movie_ratings.groupby(["userId", "rating_date", "genres"], as_index=False).agg(np.mean)

# %%
ratings_MonthGenreUserId.head(20)
# Out:
#     userId rating_date     genres      movieId    rating     timestamp
# 0        1     2009-10     Action  2823.750000  2.875000  1.256677e+09
# 1        1     2009-10  Adventure  1591.000000  1.500000  1.256677e+09
# 2        1     2009-10     Comedy  2050.333333  3.750000  1.256677e+09
# 3        1     2009-10      Crime  3439.500000  3.000000  1.256677e+09
# 4        1     2009-10      Drama  2327.500000  3.666667  1.256677e+09
# 5        1     2009-10    Fantasy  2134.000000  4.500000  1.256677e+09
# 6        1     2009-10    Romance  2575.000000  4.000000  1.256677e+09
# 7        1     2009-10     Sci-Fi  2637.500000  2.750000  1.256677e+09
# 8        1     2009-10   Thriller  2458.142857  2.642857  1.256677e+09
# 9        2     2007-10     Action   509.500000  3.500000  1.192914e+09
# 10       2     2007-10  Adventure   509.500000  3.500000  1.192914e+09
# 11       2     2007-10     Comedy  2207.666667  3.611111  1.192914e+09
# 12       2     2007-10      Crime   170.000000  3.500000  1.192914e+09
# 13       2     2007-10      Drama  1860.125000  3.812500  1.192914e+09
# 14       2     2007-10    Romance  1625.200000  3.700000  1.192914e+09
# 15       2     2007-10     Sci-Fi   849.000000  3.500000  1.192914e+09
# 16       2     2007-10   Thriller  1242.000000  3.500000  1.192914e+09
# 17       3     1999-12     Action  2028.000000  5.000000  9.451416e+08
# 18       3     1999-12  Adventure   828.000000  4.000000  9.451416e+08
# 19       3     1999-12     Comedy  1573.000000  3.500000  9.451415e+08

# %%
ratings_2017_users = ratings_MonthGenreUserId.loc[ratings_MonthGenreUserId.rating_date.isin(['2017-01',
                                                                                         '2017-02','2017-03',
                                                                                         '2017-04','2017-05',
                                                                                        '2017-06','2017-07',
                                                                                        '2017-08','2017-09',
                                                                                        '2017-10','2017-11',
                                                                                        '2017-12'])]

# %%
ratings_2017_users["Month"] = ratings_2017_users["rating_date"].apply(lambda x: x[-2:])
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x='Month', y="rating", hue="genres", data=ratings_2017_users)
plt.xlabel("Month of Year 2017", fontsize=20)
plt.ylabel("Mean Rating", fontsize=20)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(bbox_to_anchor=(1.2,0.7), fontsize=16)

plt.tight_layout()
plt.savefig("MonthlyPlot_Users.pdf")

# %% [markdown]
# ## VAR modeling

# %% [markdown]
# ### Without de-trending

# %%
# Temporal resolution: year
model = VAR(mean_ratings_year[["Drama", "Action", "Comedy", "Thriller"]]).fit(maxlags=1)
model.summary()
# Out:
# //anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:214: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 16, Sep, 2020
# Time:                     14:38:53
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   -30.7042
# Nobs:                     21.0000    HQIC:                  -31.4831
# Log likelihood:           233.648    FPE:                1.77623e-14
# AIC:                     -31.6990    Det(Omega_mle):     7.55935e-15
# --------------------------------------------------------------------
# Results for equation Drama
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const               0.553985         1.099227            0.504           0.614
# L1.Drama            1.330052         1.212677            1.097           0.273
# L1.Action           0.180642         0.315400            0.573           0.567
# L1.Comedy          -0.532869         0.762750           -0.699           0.485
# L1.Thriller        -0.162210         0.427917           -0.379           0.705
# ==============================================================================
#
# Results for equation Action
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const              -0.446959         1.343056           -0.333           0.739
# L1.Drama            1.157711         1.481671            0.781           0.435
# L1.Action           0.248136         0.385361            0.644           0.520
# L1.Comedy          -1.070510         0.931943           -1.149           0.251
# L1.Thriller         0.700854         0.522838            1.340           0.180
# ==============================================================================
#
# Results for equation Comedy
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const              -0.150495         1.404587           -0.107           0.915
# L1.Drama            1.499711         1.549552            0.968           0.333
# L1.Action           0.257744         0.403016            0.640           0.522
# L1.Comedy          -0.390419         0.974639           -0.401           0.689
# L1.Thriller        -0.425812         0.546791           -0.779           0.436
# ==============================================================================
#
# Results for equation Thriller
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const               0.383606         1.393899            0.275           0.783
# L1.Drama            1.011945         1.537761            0.658           0.510
# L1.Action           0.188836         0.399949            0.472           0.637
# L1.Comedy          -0.994955         0.967222           -1.029           0.304
# L1.Thriller         0.615984         0.542630            1.135           0.256
# ==============================================================================
#
# Correlation matrix of residuals
#                Drama    Action    Comedy  Thriller
# Drama       1.000000  0.834322  0.961844  0.941268
# Action      0.834322  1.000000  0.758338  0.904600
# Comedy      0.961844  0.758338  1.000000  0.866802
# Thriller    0.941268  0.904600  0.866802  1.000000

# %%
# Temporal resolution: month
model = VAR(mean_ratings_yearmonth[["Drama", "Action", "Comedy", "Thriller"]]).fit(maxlags=1)
model.summary()
# Out:
# //anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 16, Sep, 2020
# Time:                     14:39:07
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   -28.1699
# Nobs:                     252.000    HQIC:                  -28.3373
# Log likelihood:           2174.41    FPE:                4.40901e-13
# AIC:                     -28.4500    Det(Omega_mle):     4.07578e-13
# --------------------------------------------------------------------
# Results for equation Drama
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const               1.708758         0.194049            8.806           0.000
# L1.Drama            0.155968         0.145356            1.073           0.283
# L1.Action           0.141832         0.112516            1.261           0.207
# L1.Comedy           0.211466         0.098079            2.156           0.031
# L1.Thriller         0.049337         0.142288            0.347           0.729
# ==============================================================================
#
# Results for equation Action
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const               1.046728         0.229376            4.563           0.000
# L1.Drama           -0.167699         0.171819           -0.976           0.329
# L1.Action           0.688670         0.133000            5.178           0.000
# L1.Comedy          -0.074036         0.115934           -0.639           0.523
# L1.Thriller         0.255923         0.168192            1.522           0.128
# ==============================================================================
#
# Results for equation Comedy
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const               1.280716         0.215042            5.956           0.000
# L1.Drama           -0.105413         0.161082           -0.654           0.513
# L1.Action           0.134889         0.124689            1.082           0.279
# L1.Comedy           0.669227         0.108690            6.157           0.000
# L1.Thriller        -0.065635         0.157682           -0.416           0.677
# ==============================================================================
#
# Results for equation Thriller
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const               1.322804         0.214788            6.159           0.000
# L1.Drama           -0.242662         0.160892           -1.508           0.131
# L1.Action           0.145479         0.124542            1.168           0.243
# L1.Comedy          -0.028388         0.108561           -0.261           0.794
# L1.Thriller         0.760782         0.157496            4.830           0.000
# ==============================================================================
#
# Correlation matrix of residuals
#                Drama    Action    Comedy  Thriller
# Drama       1.000000  0.794263  0.868793  0.867797
# Action      0.794263  1.000000  0.772920  0.919146
# Comedy      0.868793  0.772920  1.000000  0.813263
# Thriller    0.867797  0.919146  0.813263  1.000000

# %% [markdown]
# ### De-trending

# %%
## Detrending
from statsmodels.tsa.tsatools import detrend
from statsmodels.tsa.stattools import adfuller

# %%
print(adfuller(mean_ratings_year[["Drama"]]))  # Stationary
print(adfuller(mean_ratings_year[["Action"]]))  # Unstationary
print(adfuller(mean_ratings_year[["Comedy"]]))  # Stationary
print(adfuller(mean_ratings_year[["Thriller"]])) # Stationary
# Out:
# (-10.96035877405361, 8.356428815531135e-20, 9, 12, {'1%': -4.137829282407408, '5%': -3.1549724074074077, '10%': -2.7144769444444443}, -100.89476880707704)
# (-1.3197587431843456, 0.6200848870891525, 9, 12, {'1%': -4.137829282407408, '5%': -3.1549724074074077, '10%': -2.7144769444444443}, -44.97347936742901)
# (-3.703220535348564, 0.004068081799419482, 9, 12, {'1%': -4.137829282407408, '5%': -3.1549724074074077, '10%': -2.7144769444444443}, -92.19414982406752)
# (-4.253418288447936, 0.0005343630361669577, 9, 12, {'1%': -4.137829282407408, '5%': -3.1549724074074077, '10%': -2.7144769444444443}, -67.41205315283426)

# %%
print(adfuller(detrend(mean_ratings_year["Action"], order=1, axis=0)))
# Out:
# (-3.133823012375228, 0.024149299254310936, 9, 12, {'1%': -4.137829282407408, '5%': -3.1549724074074077, '10%': -2.7144769444444443}, -61.44795927706495)

# %%
mean_ratings_year["Action"] = detrend(mean_ratings_year["Action"], order=1, axis=0)

# %%
# Temporal resolution: year
model = VAR(mean_ratings_year[["Drama", "Action", "Comedy", "Thriller"]]).fit(maxlags=1)
model.summary()
# Out:
# //anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:214: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 16, Sep, 2020
# Time:                     14:47:08
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   -30.4059
# Nobs:                     21.0000    HQIC:                  -31.1847
# Log likelihood:           230.516    FPE:                2.39365e-14
# AIC:                     -31.4006    Det(Omega_mle):     1.01869e-14
# --------------------------------------------------------------------
# Results for equation Drama
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const               0.850365         1.552959            0.548           0.584
# L1.Drama            1.336973         1.225258            1.091           0.275
# L1.Action           0.108577         0.255902            0.424           0.671
# L1.Comedy          -0.595834         0.764432           -0.779           0.436
# L1.Thriller        -0.014313         0.316825           -0.045           0.964
# ==============================================================================
#
# Results for equation Action
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const              -2.431359         1.879883           -1.293           0.196
# L1.Drama            1.271770         1.483195            0.857           0.391
# L1.Action           0.380817         0.309774            1.229           0.219
# L1.Comedy          -0.775415         0.925359           -0.838           0.402
# L1.Thriller         0.115924         0.383522            0.302           0.762
# ==============================================================================
#
# Results for equation Comedy
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const               0.566222         1.972175            0.287           0.774
# L1.Drama            1.453267         1.556012            0.934           0.350
# L1.Action           0.220858         0.324982            0.680           0.497
# L1.Comedy          -0.493277         0.970789           -0.508           0.611
# L1.Thriller        -0.226869         0.402351           -0.564           0.573
# ==============================================================================
#
# Results for equation Thriller
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const               0.355588         1.973099            0.180           0.857
# L1.Drama            1.083934         1.556741            0.696           0.486
# L1.Action           0.037690         0.325134            0.116           0.908
# L1.Comedy          -1.045808         0.971243           -1.077           0.282
# L1.Thriller         0.784478         0.402540            1.949           0.051
# ==============================================================================
#
# Correlation matrix of residuals
#                Drama    Action    Comedy  Thriller
# Drama       1.000000  0.817630  0.963819  0.944565
# Action      0.817630  1.000000  0.769585  0.860019
# Comedy      0.963819  0.769585  1.000000  0.876429
# Thriller    0.944565  0.860019  0.876429  1.000000

# %%
print(adfuller(mean_ratings_yearmonth[["Drama"]]))  # Untationary
print(adfuller(mean_ratings_yearmonth[["Action"]]))  # Unstationary
print(adfuller(mean_ratings_yearmonth[["Comedy"]]))  # Unstationary
print(adfuller(mean_ratings_yearmonth[["Thriller"]])) # Unstationary
# Out:
# (-2.5192708700044175, 0.11085564164987549, 6, 246, {'1%': -3.457215237265747, '5%': -2.873361841566324, '10%': -2.5730700760129555}, -815.4149788696141)
# (-2.041667897362184, 0.2686071473961835, 4, 248, {'1%': -3.4569962781990573, '5%': -2.8732659015936024, '10%': -2.573018897632674}, -758.1158847818616)
# (-2.3375670886757467, 0.16013785694468086, 5, 247, {'1%': -3.457105309726321, '5%': -2.873313676101283, '10%': -2.5730443824681606}, -764.5044921088003)
# (-2.2148100909802073, 0.20091422522214586, 4, 248, {'1%': -3.4569962781990573, '5%': -2.8732659015936024, '10%': -2.573018897632674}, -780.3415591878493)

# %%
print(adfuller(detrend(mean_ratings_yearmonth[["Drama", "Action", "Comedy", "Thriller"]], order=2, axis=0)["Drama"]))
print(adfuller(detrend(mean_ratings_yearmonth[["Drama", "Action", "Comedy", "Thriller"]], order=2, axis=0)["Action"]))
print(adfuller(detrend(mean_ratings_yearmonth[["Drama", "Action", "Comedy", "Thriller"]], order=2, axis=0)["Comedy"]))
print(adfuller(detrend(mean_ratings_yearmonth[["Drama", "Action", "Comedy", "Thriller"]], order=2, axis=0)["Thriller"]))
# Out:
# (-3.5410838073425492, 0.006992577078734866, 4, 248, {'1%': -3.4569962781990573, '5%': -2.8732659015936024, '10%': -2.573018897632674}, -815.8468732338315)
# (-2.3997519114108776, 0.14180644210162685, 4, 248, {'1%': -3.4569962781990573, '5%': -2.8732659015936024, '10%': -2.573018897632674}, -758.7395124841274)
# (-3.454306258475826, 0.009241144302746352, 3, 249, {'1%': -3.4568881317725864, '5%': -2.8732185133016057, '10%': -2.5729936189738876}, -765.8672396667131)
# (-2.5029673745925543, 0.11475399891475246, 4, 248, {'1%': -3.4569962781990573, '5%': -2.8732659015936024, '10%': -2.573018897632674}, -780.7900915779874)

# %%
# Temporal resolution: month
model = VAR(detrend(mean_ratings_yearmonth[["Drama", "Action", "Comedy", "Thriller"]], order=1, axis=0)).fit(maxlags=1, ic='aic')
model.summary()
# Out:
# //anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 16, Sep, 2020
# Time:                     14:50:40
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   -28.4106
# Nobs:                     252.000    HQIC:                  -28.5780
# Log likelihood:           2204.74    FPE:                3.46559e-13
# AIC:                     -28.6907    Det(Omega_mle):     3.20367e-13
# --------------------------------------------------------------------
# Results for equation Drama
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const              -0.000469         0.002931           -0.160           0.873
# L1.Drama            0.172492         0.145700            1.184           0.236
# L1.Action           0.123117         0.113418            1.086           0.278
# L1.Comedy           0.284852         0.117135            2.432           0.015
# L1.Thriller        -0.034867         0.160016           -0.218           0.828
# ==============================================================================
#
# Results for equation Action
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const              -0.000867         0.003410           -0.254           0.799
# L1.Drama           -0.116364         0.169533           -0.686           0.492
# L1.Action           0.630532         0.131971            4.778           0.000
# L1.Comedy           0.153936         0.136296            1.129           0.259
# L1.Thriller        -0.005642         0.186191           -0.030           0.976
# ==============================================================================
#
# Results for equation Comedy
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const              -0.000794         0.003251           -0.244           0.807
# L1.Drama           -0.119085         0.161656           -0.737           0.461
# L1.Action           0.150388         0.125839            1.195           0.232
# L1.Comedy           0.608447         0.129963            4.682           0.000
# L1.Thriller         0.004164         0.177540            0.023           0.981
# ==============================================================================
#
# Results for equation Thriller
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const              -0.000666         0.003170           -0.210           0.834
# L1.Drama           -0.186137         0.157610           -1.181           0.238
# L1.Action           0.081456         0.122689            0.664           0.507
# L1.Comedy           0.222660         0.126710            1.757           0.079
# L1.Thriller         0.472721         0.173096            2.731           0.006
# ==============================================================================
#
# Correlation matrix of residuals
#                Drama    Action    Comedy  Thriller
# Drama       1.000000  0.797093  0.876228  0.876020
# Action      0.797093  1.000000  0.798846  0.916117
# Comedy      0.876228  0.798846  1.000000  0.847910
# Thriller    0.876020  0.916117  0.847910  1.000000
