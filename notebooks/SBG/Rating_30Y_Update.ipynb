# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sc

# %%
# Import cleaned datasets
MRM=pd.read_csv('mean_ratings_yearmonth.csv')
# Next, reshape datasets

# %%
import statsmodels.api as sm
from random import random
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import acf,pacf,plot_acf,plot_pacf
from statsmodels.tsa.arima_model import ARMA, ARIMA
from matplotlib.backends.backend_pdf import PdfPages
from statsmodels.tsa.stattools import adfuller

# %%
# Consider months first
Months_M=MRM.pivot(index='rating_date',columns='genres',values='rating')

# %%
Months_M
# Out:
# genres         Action  Adventure    Comedy     Crime     Drama   Fantasy  \
# rating_date
# 1997-09      3.497851   3.614968  3.547915  3.722609  3.706409  3.587582
# 1997-10      3.505801   3.590452  3.468590  3.695402  3.665669  3.527335
# 1997-11      3.411883   3.529372  3.466164  3.669048  3.664561  3.543101
# 1997-12      3.424951   3.537306  3.461299  3.664982  3.640967  3.507917
# 1998-01      3.369930   3.474170  3.345554  3.540208  3.507089  3.402778
# ...               ...        ...       ...       ...       ...       ...
# 2018-05      3.517145   3.544951  3.438787  3.703371  3.699815  3.494306
# 2018-06      3.545266   3.575223  3.467511  3.724195  3.716126  3.531271
# 2018-07      3.525763   3.551949  3.449227  3.724967  3.695628  3.498392
# 2018-08      3.507507   3.557175  3.414390  3.695318  3.662569  3.518765
# 2018-09      3.386111   3.441283  3.323526  3.630549  3.593279  3.414203
#
# genres        Romance    Sci-Fi  Thriller
# rating_date
# 1997-09      3.645617  3.594025  3.519164
# 1997-10      3.598263  3.597502  3.497024
# 1997-11      3.590192  3.513699  3.437533
# 1997-12      3.553970  3.518480  3.425153
# 1998-01      3.496704  3.455460  3.376575
# ...               ...       ...       ...
# 2018-05      3.546896  3.546816  3.563887
# 2018-06      3.598700  3.579804  3.577264
# 2018-07      3.516012  3.568202  3.563761
# 2018-08      3.518282  3.557812  3.527500
# 2018-09      3.441228  3.423907  3.438624
#
# [253 rows x 9 columns]

# %%
def TestStationaryAdfuller(ts, cutoff = 0.01):
    ts_test = adfuller(ts, autolag = 'AIC')
    ts_test_output = pd.Series(ts_test[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])

    for key,value in ts_test[4].items():
        ts_test_output['Critical Value (%s)'%key] = value
    print(ts_test_output)

    if ts_test[1] <= cutoff:
        print('Reject--Stationary')
    else:
        print('Not reject--Not Stationary')

# %%
# First of all, test stationary
for i in Months_M.columns:
    print('Genre: '+i)
    TestStationaryAdfuller(Months_M[i])
# Out:
# Genre: Action
# Test Statistic                  -2.041668
# p-value                          0.268607
# #Lags Used                       4.000000
# Number of Observations Used    248.000000
# Critical Value (1%)             -3.456996
# Critical Value (5%)             -2.873266
# Critical Value (10%)            -2.573019
# dtype: float64
# Not reject--Not Stationary
# Genre: Adventure
# Test Statistic                  -2.495656
# p-value                          0.116535
# #Lags Used                       4.000000
# Number of Observations Used    248.000000
# Critical Value (1%)             -3.456996
# Critical Value (5%)             -2.873266
# Critical Value (10%)            -2.573019
# dtype: float64
# Not reject--Not Stationary
# Genre: Comedy
# Test Statistic                  -2.337567
# p-value                          0.160138
# #Lags Used                       5.000000
# Number of Observations Used    247.000000
# Critical Value (1%)             -3.457105
# Critical Value (5%)             -2.873314
# Critical Value (10%)            -2.573044
# dtype: float64
# Not reject--Not Stationary
# Genre: Crime
# Test Statistic                  -2.793775
# p-value                          0.059169
# #Lags Used                       3.000000
# Number of Observations Used    249.000000
# Critical Value (1%)             -3.456888
# Critical Value (5%)             -2.873219
# Critical Value (10%)            -2.572994
# dtype: float64
# Not reject--Not Stationary
# Genre: Drama
# Test Statistic                  -2.519271
# p-value                          0.110856
# #Lags Used                       6.000000
# Number of Observations Used    246.000000
# Critical Value (1%)             -3.457215
# Critical Value (5%)             -2.873362
# Critical Value (10%)            -2.573070
# dtype: float64
# Not reject--Not Stationary
# Genre: Fantasy
# Test Statistic                  -4.892808
# p-value                          0.000036
# #Lags Used                       1.000000
# Number of Observations Used    251.000000
# Critical Value (1%)             -3.456674
# Critical Value (5%)             -2.873125
# Critical Value (10%)            -2.572944
# dtype: float64
# Reject--Stationary
# Genre: Romance
# Test Statistic                  -1.859960
# p-value                          0.351125
# #Lags Used                       6.000000
# Number of Observations Used    246.000000
# Critical Value (1%)             -3.457215
# Critical Value (5%)             -2.873362
# Critical Value (10%)            -2.573070
# dtype: float64
# Not reject--Not Stationary
# Genre: Sci-Fi
# Test Statistic                  -1.010667
# p-value                          0.749354
# #Lags Used                       7.000000
# Number of Observations Used    245.000000
# Critical Value (1%)             -3.457326
# Critical Value (5%)             -2.873410
# Critical Value (10%)            -2.573096
# dtype: float64
# Not reject--Not Stationary
# Genre: Thriller
# Test Statistic                  -2.214810
# p-value                          0.200914
# #Lags Used                       4.000000
# Number of Observations Used    248.000000
# Critical Value (1%)             -3.456996
# Critical Value (5%)             -2.873266
# Critical Value (10%)            -2.573019
# dtype: float64
# Not reject--Not Stationary

# %%
# After test, only the Fantasy series is stationary
# Then consider extracting the difference
Dif_DT=pd.DataFrame()
for i in Months_M.columns:
    if i!='Fantasy':
        Dif=Months_M[i]-Months_M[i].shift(1)
        # Remove the seasonal trend
        Dif_sea=Dif-Dif.shift(12)
        s='Dif_'+i
        Dif_DT[s]=Dif_sea
        print('Difference of '+i)
        TestStationaryAdfuller(Dif_sea.dropna(inplace=False))
    else:
        Dif_DT[i]=Months_M[i]
# Out:
# Difference of Action
# Test Statistic                -6.804939e+00
# p-value                        2.188880e-09
# #Lags Used                     1.200000e+01
# Number of Observations Used    2.270000e+02
# Critical Value (1%)           -3.459490e+00
# Critical Value (5%)           -2.874358e+00
# Critical Value (10%)          -2.573602e+00
# dtype: float64
# Reject--Stationary
# Difference of Adventure
# Test Statistic                -5.785495e+00
# p-value                        5.010705e-07
# #Lags Used                     1.200000e+01
# Number of Observations Used    2.270000e+02
# Critical Value (1%)           -3.459490e+00
# Critical Value (5%)           -2.874358e+00
# Critical Value (10%)          -2.573602e+00
# dtype: float64
# Reject--Stationary
# Difference of Comedy
# Test Statistic                  -5.579406
# p-value                          0.000001
# #Lags Used                      13.000000
# Number of Observations Used    226.000000
# Critical Value (1%)             -3.459620
# Critical Value (5%)             -2.874415
# Critical Value (10%)            -2.573632
# dtype: float64
# Reject--Stationary
# Difference of Crime
# Test Statistic                -6.877148e+00
# p-value                        1.464691e-09
# #Lags Used                     1.400000e+01
# Number of Observations Used    2.250000e+02
# Critical Value (1%)           -3.459752e+00
# Critical Value (5%)           -2.874473e+00
# Critical Value (10%)          -2.573663e+00
# dtype: float64
# Reject--Stationary
# Difference of Drama
# Test Statistic                -6.462295e+00
# p-value                        1.433275e-08
# #Lags Used                     1.400000e+01
# Number of Observations Used    2.250000e+02
# Critical Value (1%)           -3.459752e+00
# Critical Value (5%)           -2.874473e+00
# Critical Value (10%)          -2.573663e+00
# dtype: float64
# Reject--Stationary
# Difference of Romance
# Test Statistic                -5.761476e+00
# p-value                        5.659107e-07
# #Lags Used                     1.300000e+01
# Number of Observations Used    2.260000e+02
# Critical Value (1%)           -3.459620e+00
# Critical Value (5%)           -2.874415e+00
# Critical Value (10%)          -2.573632e+00
# dtype: float64
# Reject--Stationary
# Difference of Sci-Fi
# Test Statistic                -5.705606e+00
# p-value                        7.500864e-07
# #Lags Used                     1.300000e+01
# Number of Observations Used    2.260000e+02
# Critical Value (1%)           -3.459620e+00
# Critical Value (5%)           -2.874415e+00
# Critical Value (10%)          -2.573632e+00
# dtype: float64
# Reject--Stationary
# Difference of Thriller
# Test Statistic                  -5.581770
# p-value                          0.000001
# #Lags Used                      12.000000
# Number of Observations Used    227.000000
# Critical Value (1%)             -3.459490
# Critical Value (5%)             -2.874358
# Critical Value (10%)            -2.573602
# dtype: float64
# Reject--Stationary

# %%
# Now testing the white noise
for i in Dif_DT.columns:
    s=Dif_DT[i].copy()
    s.dropna(inplace=True)
    r,q,p = sm.tsa.acf(s.values.squeeze(), qstat=True) 
    data = np.c_[range(1,41), r[1:], q, p] 
    table = pd.DataFrame(data, columns=['lag', "AC", "Q", "Prob(>Q)"]) 
    print('Group: '+i)
    print(table.set_index('lag'))
# From the result all of the time series can reject the white noise hypothesis
# Out:
# Group: Dif_Action
#             AC           Q      Prob(>Q)
# lag
# 1.0  -0.472001   54.139453  1.867536e-13
# 2.0   0.029208   54.347641  1.579646e-12
# 3.0  -0.059017   55.201185  6.220041e-12
# 4.0   0.035075   55.503958  2.547631e-11
# 5.0  -0.012691   55.543765  1.008871e-10
# 6.0  -0.040441   55.949705  2.979925e-10
# 7.0   0.017977   56.030262  9.314195e-10
# 8.0   0.062391   57.004778  1.796876e-09
# 9.0  -0.080367   58.628712  2.461466e-09
# 10.0  0.040883   59.050776  5.478147e-09
# 11.0  0.208218   70.046546  1.197037e-10
# 12.0 -0.460593  124.087876  9.436755e-21
# 13.0  0.222050  136.703334  9.616052e-23
# 14.0 -0.005859  136.712156  3.190905e-22
# 15.0  0.061920  137.701866  6.532307e-22
# 16.0 -0.026332  137.881654  1.870764e-21
# 17.0 -0.027571  138.079636  5.147010e-21
# 40.0  0.006760  196.684011  1.443854e-22
# Group: Dif_Thriller
#             AC           Q      Prob(>Q)
# lag
# 1.0  -0.463135   52.124813  5.208261e-13
# 2.0  -0.036227   52.445085  4.089729e-12
# 3.0   0.048481   53.021073  1.814494e-11
# 4.0  -0.038431   53.384559  7.080256e-11
# 5.0   0.035895   53.702992  2.412057e-10
# 6.0  -0.062528   54.673398  5.395499e-10
# 7.0   0.012685   54.713507  1.699030e-09
# 8.0   0.106024   57.527667  1.420503e-09
# 9.0  -0.152162   63.349049  3.018897e-10
# 10.0  0.073731   64.721808  4.581515e-10
# 11.0  0.240670   79.412244  1.916943e-12
# 12.0 -0.460084  133.334247  1.319836e-22
# 13.0  0.187315  142.311527  7.240715e-24
# 14.0  0.030687  142.553529  2.202153e-23
# 15.0 -0.022540  142.684674  6.790176e-23
# 16.0  0.036960  143.038874  1.828390e-22
# 17.0 -0.060393  143.988797  3.654233e-22
# 18.0  0.093465  146.274249  3.926910e-22
# 19.0 -0.024113  146.427055  1.068875e-21
# 20.0 -0.131525  150.993980  4.054626e-22
# 21.0  0.173791  159.004069  3.360579e-23
# 22.0 -0.118334  162.734742  1.834274e-23
# 23.0  0.030067  162.976698  4.571608e-23
# 24.0 -0.034960  163.305332  1.074315e-22
# 25.0  0.051667  164.026465  2.090203e-22
# 26.0  0.015771  164.093970  5.290633e-22
# 27.0 -0.047455  164.708030  1.040997e-21
# 28.0 -0.040482  165.156994  2.162069e-21
# 29.0  0.091353  167.454156  2.033419e-21
# 30.0 -0.053778  168.254010  3.553440e-21
# 31.0  0.002315  168.255500  8.540215e-21
# 32.0  0.047667  168.889953  1.555068e-20
# 33.0 -0.072097  170.348415  1.994424e-20
# 34.0  0.084173  172.346004  2.035633e-20
# 35.0 -0.083402  174.316722  2.088396e-20
# 36.0  0.084823  176.365166  2.064583e-20
# 37.0 -0.049652  177.070517  3.488667e-20
# 38.0 -0.027293  177.284700  7.102040e-20
# 39.0  0.067207  178.589859  9.255884e-20
# 40.0  0.060223  179.643089  1.323618e-19
# /Users/lihuayu/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:541: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(msg, FutureWarning)
# /Users/lihuayu/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:541: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(msg, FutureWarning)
# /Users/lihuayu/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:541: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(msg, FutureWarning)
# /Users/lihuayu/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:541: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(msg, FutureWarning)
# /Users/lihuayu/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:541: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(msg, FutureWarning)
# /Users/lihuayu/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:541: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(msg, FutureWarning)
# /Users/lihuayu/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:541: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(msg, FutureWarning)
# /Users/lihuayu/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:541: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(msg, FutureWarning)
# /Users/lihuayu/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:541: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(msg, FutureWarning)

# %%
# Start fitting SARMA model
def SAR(p,q,P,Q,col,d=1,D=1):
    ordi=(p,d,q)
    seas=(P,D,Q,12)
    model=SARIMAX(Months_M[col],order=ordi,seasonal_order=seas)
    model_fit=model.fit(disp=False)
    t=model_fit.predict(1,)
    lab=model_fit.predict().index
    pred=Months_M.copy()[col]
    pred.iloc[1:]=t
    pred.index=lab
    init=Months_M[col].copy()
    init.index=lab
    S=model_fit.params
    PS=pd.DataFrame(S,columns=['params'])
    PS['CI_2.5%']=model_fit.conf_int()[0]
    PS['CI_97.5%']=model_fit.conf_int()[1]
    return [PS,pred,init,model_fit]

# %%
pdf = PdfPages("SARMA_mean.pdf")

# %%
Dic_result=dict()
Predictor=dict()
for genre in Months_M.columns:
    if genre!='Fantasy' and genre!='Thriller':
        New=SAR(1,1,1,1,genre,1,1)
    elif genre=='Fantasy':
        New=SAR(1,1,1,1,genre,0,0)
    else:
        New=SAR(1,1,1,1,genre,1,1)
    Dic_result[genre]=New[0]
    Predictor[genre]=New[3]
    plt.plot(New[2][13:])
    plt.plot(New[1][13:])
    expr='Rating of '+genre+'s'
    plt.title(expr)
    pdf.savefig()
    plt.close()
pdf.close()
# Out:
# /Users/lihuayu/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/lihuayu/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/lihuayu/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/lihuayu/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/lihuayu/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/lihuayu/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/lihuayu/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/lihuayu/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/lihuayu/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/lihuayu/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/lihuayu/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
Dic_result
# Out:
# {'Action':             params   CI_2.5%  CI_97.5%
#  ar.L1     0.099383 -0.091135  0.289902
#  ma.L1    -0.788264 -0.904690 -0.671839
#  ar.S.L12  0.074719 -0.094515  0.243954
#  ma.S.L12 -0.985933 -1.927579 -0.044287
#  sigma2    0.002307  0.000295  0.004318,
#  'Adventure':             params   CI_2.5%  CI_97.5%
#  ar.L1     0.093787 -0.104337  0.291911
#  ma.L1    -0.784483 -0.910391 -0.658576
#  ar.S.L12  0.121764 -0.060230  0.303758
#  ma.S.L12 -0.949099 -1.226088 -0.672110
#  sigma2    0.002031  0.001560  0.002502,
#  'Comedy':             params   CI_2.5%  CI_97.5%
#  ar.L1     0.071986 -0.136386  0.280359
#  ma.L1    -0.758952 -0.902376 -0.615529
#  ar.S.L12  0.050582 -0.122407  0.223572
#  ma.S.L12 -0.948270 -1.196342 -0.700198
#  sigma2    0.002262  0.001771  0.002754,
#  'Crime':             params   CI_2.5%  CI_97.5%
#  ar.L1     0.022898 -0.174264  0.220061
#  ma.L1    -0.731005 -0.872075 -0.589936
#  ar.S.L12 -0.046869 -0.186323  0.092585
#  ma.S.L12 -0.906875 -1.057776 -0.755975
#  sigma2    0.002287  0.001890  0.002683,
#  'Drama':             params   CI_2.5%  CI_97.5%
#  ar.L1     0.078460 -0.100487  0.257408
#  ma.L1    -0.763890 -0.890905 -0.636875
#  ar.S.L12  0.024712 -0.132813  0.182237
#  ma.S.L12 -0.889530 -1.023788 -0.755273
#  sigma2    0.002024  0.001686  0.002362,
#  'Fantasy':             params   CI_2.5%  CI_97.5%
#  ar.L1     0.999894  0.998348  1.001440
#  ma.L1    -0.903714 -0.942333 -0.865094
#  ar.S.L12  0.999839  0.998527  1.001152
#  ma.S.L12 -0.975565 -1.061080 -0.890051
#  sigma2    0.002373  0.002017  0.002729,
#  'Romance':             params   CI_2.5%  CI_97.5%
#  ar.L1     0.183952 -0.009748  0.377652
#  ma.L1    -0.787271 -0.913312 -0.661230
#  ar.S.L12  0.099041 -0.071264  0.269345
#  ma.S.L12 -0.957161 -1.203294 -0.711029
#  sigma2    0.002196  0.001657  0.002735,
#  'Sci-Fi':             params   CI_2.5%  CI_97.5%
#  ar.L1    -0.028525 -0.222996  0.165945
#  ma.L1    -0.699714 -0.850402 -0.549026
#  ar.S.L12 -0.042503 -0.200868  0.115861
#  ma.S.L12 -0.875828 -1.014720 -0.736935
#  sigma2    0.002252  0.001892  0.002612,
#  'Thriller':             params   CI_2.5%  CI_97.5%
#  ar.L1     0.049618 -0.159118  0.258353
#  ma.L1    -0.753839 -0.897842 -0.609837
#  ar.S.L12  0.063147 -0.102375  0.228669
#  ma.S.L12 -0.959582 -1.255194 -0.663971
#  sigma2    0.002106  0.001547  0.002664}

# %%
# Future predictions
pdf = PdfPages("Future_pred.pdf")
for res in Predictor:
    ftr=Predictor[res].forecast(steps=120)
    plt.plot(ftr)
    expr='Future of '+ res
    plt.title(expr)
    pdf.savefig()
    plt.close()
pdf.close()
